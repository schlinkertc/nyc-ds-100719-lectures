# %% [markdown]
# # Matplotlib Applied

# %% [markdown]
# **Aim: SWBAT create a figure with 4 subplot of varying graph types.**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from numpy.random import seed, randint
seed(100)

# Create Figure and Subplots
fig, axes = plt.subplots(2,2, figsize=(10,6), sharex=True, sharey=True, dpi=120)

# Define the colors and markers to use
colors = {0:'g', 1:'b', 2:'r', 3:'y'}
markers = {0:'o', 1:'x', 2:'*', 3:'p'}

# Plot each axes
for i, ax in enumerate(axes.ravel()):
    ax.plot(sorted(randint(0,10,10)), sorted(randint(0,10,10)), marker=markers[i], color=colors[i])  
    ax.set_title('Ax: ' + str(i))
    ax.yaxis.set_ticks_position('default')

plt.suptitle('Four Subplots in One Figure', verticalalignment='bottom', fontsize=16)    
plt.tight_layout()
# plt.show()

# %%
list(enumerate(np.ravel(axes)))
# Out:
# [(0, <matplotlib.axes._subplots.AxesSubplot at 0x1131d9898>),
#  (1, <matplotlib.axes._subplots.AxesSubplot at 0x113accc50>),
#  (2, <matplotlib.axes._subplots.AxesSubplot at 0x113312240>),
#  (3, <matplotlib.axes._subplots.AxesSubplot at 0x1133427f0>)]

# %% [markdown]
# ### Go through and play  with the code above to try answer the questions below:
#
# - What do you think `sharex` and `sharey` do?
#
# Sharex and sharey stipulate that subplots' respective axes are the same
#
# - What does the `dpi` argument control?
#
# dpi = dots per inches
#
# - What does `numpy.ravel()` do, and why do they call it here?
#
# np.ravel returns a flattened array. It turns multiple lists into one.
#
# - What does `yaxis.set_ticks_position()` do?
#
# set_ticks_position() accepts a string and determines where the data ticks go on the Y axis (left, right, both, default, or none)
#
# - How do they use the `colors` and `markers` dictionaries?
#
# They use the dictionaries to set colors and markers for the subplots in a for loop. The enumerate function in the for loop provides the index numbers for the sub plots, which correspond to the keys in the dictionary.

# %%
fig.savefig('saved.png')

# %% [markdown]
# ### Your turn:
#
# - Create a figure that has 4 sub plots on it.
#
# - Plot 1: a line blue graph (`.plot()`) using data `x` and `y`
#
# - Plot 2: a scatter plot (`.scatter()`) using data `x2` and `y2` with red markers that are non-filled circles.
#
# - Plot 3: a plot that has both a line graph (x and y data) and a scatterplot (x2, y2) that only use 1 y axis
#
# - plot 4: a plot that is similiar to plot3 except the scatter plot has it own axis on the right hand side.
#
# - Put titles on each subplot.
#
# - Create a title for the entire figure.
#
# - Save figure as png.

# %%
from numpy.random import seed, randint
seed(100)

myfig, axes = plt.subplots(2,2, figsize=(12,8), sharex=False, sharey=False, dpi=120)


x = sorted(randint(0,10,10))
x2 = sorted(randint(0,20,10))
y = sorted(randint(0,10,10))
y2 = sorted(randint(0,20,10))

axes[0,0].plot(x,y)
axes[0,1].scatter(x2,y2,color='r',facecolors='none',edgecolors='r')
axes[1,0].plot(x,y)
axes[1,0].scatter(x2,y2,color='r',facecolors='none',edgecolors='r')
axes[1,1].plot(x,y)
ax2 = axes[1][1].twinx()
ax2.scatter(x2,y2,color='r',facecolors='none',edgecolors='r')
axes[1,1].yaxis.set_ticks_position('both')

axes[0,0].title.set_text('First Plot')
axes[0,1].title.set_text('Second Plot')
axes[1,0].title.set_text('Third Plot')
axes[1,1].title.set_text('Fourth Plot')

myfig.suptitle('My Shitty Figure')
myfig.savefig('MyShittyFigure.png')

# %% [markdown]
# ## Great tutorial on matplotlib
#
# https://www.machinelearningplus.com/plots/matplotlib-tutorial-complete-guide-python-plot-examples/

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e0f2400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d450e80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10d49e400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d4c4978>]],
#       dtype=object)

# %%
# Out:
# Text(0.5, 1.0, 'Ax: 4')

# %%
fig
